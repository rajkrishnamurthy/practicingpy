# %%
import pandas as pd
import numpy as np

# from bokeh.charts import HeatMap, bins, output_notebook, show, vplot
# from bokeh.palettes import RdYlGn6, RdYlGn9
import holoviews as hv
hv.extension('bokeh')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-7a73689e340c> in <module>()
#       2 import numpy as np
#       3
# ----> 4 from bokeh.charts import HeatMap, bins, output_notebook, show, vplot
#       5 from bokeh.palettes import RdYlGn6, RdYlGn9
#       6 # import holoviews as hv
#
# ModuleNotFoundError: No module named 'bokeh.charts'

# %%
from bokeh.plotting import figure

# %%
p=figure()

# %%
p.x_range=

# %%
dataFrame=pd.read_csv('out.csv').drop('Unnamed: 0', axis=1).reindex()
cols=['cumnum','control_name']
controldomains=dataFrame[dataFrame['root']==True][cols]
controldomains['score']=-1  # score should be between 0 and 100. Initial assignment of -1 to differentiate from later assignments

# %%
hv.help(hv.HeatMap)
# Out:
# HeatMap
#
# Online example: http://holoviews.org/reference/elements/bokeh/HeatMap.html
#
# -------------
# Style Options
# -------------
#
# ...

# %%
hv.HeatMap(subdf)
# Out:
# :HeatMap   [impact,frequency]   (weight)
